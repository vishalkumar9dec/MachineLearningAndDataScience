# %%
from bs4 import BeautifulSoup
import requests

# %%
#webscarpping, giving the websiteURL
source=requests.get('http://www.simplilearn.com').text
soup= BeautifulSoup(source, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Online Certification Training Courses for Professionals | Simplilearn
#   </title>
#   <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://js-agent.newrelic.com" rel="dns-prefetch"/>
#   <link href="https://rum-static.pingdom.net" rel="dns-prefetch"/>
#   <script type="text/javascript">
# ...

# %%
print(soup.find('title'))
# Out:
# <title>Online Certification Training Courses for Professionals | Simplilearn</title>

# %%
print(soup.find('a')['href'])
# Out:
# https://www.simplilearn.com/resources

# %%
i=1
for link in soup.find_all('link'):
    print('Link%d: ' %(i), link['href'])
    i+=1


j=i
for alink in soup.find_all('a'):
    try:
        print('Link%d: ' %(j), alink['href'])
        j+=1
    except Exception as e:
        print('OOPS ! Link not found')
# Out:
# Link1:  https://ssl.google-analytics.com
# Link2:  https://js-agent.newrelic.com
# Link3:  https://rum-static.pingdom.net
# Link4:  https://www.simplilearn.com/static/frontend/images/favicon.png
# Link5:  https://www.simplilearn.com/static-frs/manifest.json
# Link6:  https://www.simplilearn.com/static/frontend/images/favicon/favicon.ico
# Link7:  https://www.simplilearn.com/static/frontend/images/favicon/apple-touch-icon-152x152.png
# Link8:  https://www.simplilearn.com/static/frontend/images/favicon/apple-touch-icon-120x120.png
# Link9:  https://www.simplilearn.com/static/frontend/images/favicon/apple-touch-icon-76x76.png
# Link10:  https://www.simplilearn.com/static/frontend/images/favicon/apple-touch-icon-60x60.png
# Link11:  https://www.simplilearn.com/static/frontend/images/favicon/safari-pinned-tab.svg
# Link12:  https://www.simplilearn.com/feed/
# Link13:  /simpli_search.xml
# Link14:  https://www.simplilearn.com
# Link15:  https://www.simplilearn.com/resources
# ...

# %%
#Assignment 2

# %%
from bs4 import BeautifulSoup
import requests

# %%
source = requests.get('http://www.simplilearn.com/resources').content

soup = BeautifulSoup(source, 'lxml')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en-US" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <title>
#    Resources | Free Resources to shape your Career - Simplilearn
#   </title>
#   <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
#   <link href="https://js-agent.newrelic.com" rel="dns-prefetch"/>
#   <link href="https://rum-static.pingdom.net" rel="dns-prefetch"/>
#   <script type="text/javascript">
# ...

# %%
print(soup.head)
# Out:
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <title>Resources | Free Resources to shape your Career - Simplilearn</title>
# <link href="https://ssl.google-analytics.com" rel="dns-prefetch"/>
# <link href="https://js-agent.newrelic.com" rel="dns-prefetch"/>
# <link href="https://rum-static.pingdom.net" rel="dns-prefetch"/>
# <script type="text/javascript">
# ...

# %%
print(soup.title)
# Out:
# <title>Resources | Free Resources to shape your Career - Simplilearn</title>

# %%
for href in soup.find_all('a', href=True):
    print(href['href'])
# Out:
# https://www.simplilearn.com
#
# https://www.simplilearn.com/artificial-intelligence-career-guide-pdf?source=frs_home_carousal
# https://www.simplilearn.com/new-destination-for-ai-and-machine-learning-training-simplilearn-and-purdue-university-article?source=frs_home_carousal
# https://www.simplilearn.com/future-in-data-science-career-outlook-webinar?source=frs_home_carousal
# https://www.simplilearn.com/big-data-career-guide-pdf?source=frs_home_carousal
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# javascript:void(0);
# #agile-and-scrum
# #big-data-and-analytics
# #digital-marketing
# #it-security-management
# #it-service-and-architecture
# #project-management
# #salesforce-training
# #virtualization-and-cloud-computing
# #career-fast-track
# #enterprise
# #digital-transformation
# #other-segments
# https://www.simplilearn.com/resources/agile-and-scrum?source=frs_home
# https://www.simplilearn.com/how-to-become-certified-scrum-master-article?source=frs_home
# ...

# %%
print(soup.find('header').text)
# Out:
# All Courses Log in

# %%
for headers in soup.find_all('header'):
    print(headers.text)
# Out:
# All Courses Log in

# %%
for topics in soup.find_all('h2'):
    print(topics.text)
# Out:
# Artificial Intelligence Career Guide: A Comprehensive Playbook to Becoming an AI Expert
# The New Destination for AI and Machine Learning Training: Simplilearn + Purdue University
# Your Future in Data Science: Career Outlook for 2020
# Big Data Career Guide: A Comprehensive Playbook to Becoming a Big Data Engineer

# %%
print(soup.find('article'))
# Out:
# None

# %%
BeautifulSoup("Sacr&eacute; bleu!")
# Out:
# <html><body><p>Sacré bleu!</p></body></html>

# %%
soup = BeautifulSoup('<b class="boldest">Extremely Bold</b>')
tag = soup.b
type(tag)
# Out:
# bs4.element.Tag

# %%
#print(tag.name)
tag.name
# Out:
# 'b'

# %%
tag.name='bold'
tag.name
# Out:
# 'bold'

# %%
#accessing the tag's attribute. It can be accessed just like dictionary
tag['class']
# Out:
# ['boldest']

# %%
#dictionary can be accessed as 
tag.attrs
# Out:
# {'class': ['boldest']}

# %%
print(soup)
# Out:
# <html><body><bold class="boldest">Extremely Bold</bold></body></html>

# %%
tag['id'] = 1
tag.attrs
# Out:
# {'class': ['boldest'], 'id': 1}

# %%
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <bold class="boldest" id="1">
#    Extremely Bold
#   </bold>
#  </body>
# </html>

# %%
print(soup.find('bold'))
# Out:
# <bold class="boldest" id="1">Extremely Bold</bold>

# %%
print(tag.get('class'))

# %%
multivalue = BeautifulSoup('<p class="body strikeout"></p>')

# %%
print(multivalue.find('p'))
# Out:
# <p class="body strikeout"></p>

# %%
multival = multivalue.p

# %%
multival.attrs
# Out:
# {'class': ['body', 'strikeout']}

# %%
tag.string
# Out:
# 'Extremely Bold'

# %%
print(type(tag.string))
# Out:
# <class 'bs4.element.NavigableString'>

# %%
doc = BeautifulSoup('<document><content/>INSERT FOOTER HERE</document>', 'xml')
footer=BeautifulSoup('<footer>Here is the footer</footer>','xml')
doc.find(text='INSERT FOOTER HERE').replace_with(footer)
print(doc)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <document><content/><footer>Here is the footer</footer></document>

# %%
print(doc)
# Out:
# <html><body><document><content></content>INSERT FOOTER HERE</document></body></html>

# %%
footer=BeautifulSoup('<footer>Here is the footer</footer>', 'lxml')
print(footer)
# Out:
# <html><body><footer>Here is the footer</footer></body></html>

# %%
tag.contents
# Out:
# ['Extremely Bold']

# %%
import re

# %%
for tag in soup.find_all(re.compile("b")):
    print(tag.name)
# Out:
# body
# bold

# %%
print(soup)
# Out:
# <html><body><bold class="boldest" id="1">Extremely Bold</bold></body></html>

# %%
soup.find_all(["html", "body"])
# Out:
# [<html><body><bold class="boldest" id="1">Extremely Bold</bold></body></html>,
#  <body><bold class="boldest" id="1">Extremely Bold</bold></body>]

# %%
for tag in soup.find_all(True):
    print(tag.name)
# Out:
# html
# body
# bold
