# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
# %matplotlib inline

# %%
x = np.linspace(0,10,15)
print(x)
plt.plot(x,x,label='Linear')
plt.legend()
plt.show()
# Out:
# [ 0.          0.71428571  1.42857143  2.14285714  2.85714286  3.57142857
#   4.28571429  5.          5.71428571  6.42857143  7.14285714  7.85714286
#   8.57142857  9.28571429 10.        ]

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([1,2,3,4],[10,20,25,30],color='lightblue',linewidth=3)
ax.scatter([0.3,3.8,1.2,2.5],[11,25,9,26], color='lightgreen', linewidth=2)
ax.set_xlim(0.5, 4.5)
plt.show()

# %%
plt.plot([1,2,3,4],[10,20,25,30],color='lightblue',linewidth=3)
#plt.scatter([0.3,3.8,1.2,2.5],[11,25,9,26], color='lightgreen', linewidth=2)
plt.xlim(0.5, 4.5)
plt.show()

# %%
fig = plt.figure()
fig.add_axes([1,1,1,1])

# %%
fig = plt.figure()
ax = plot.add_subplot(121)
ay = plot.add_subplot(122)
ax.scatter(np.linspace(0,2,5), np.linspace(0,5,5))
#pict = plt.figure()

ay.scatter(np.linspace(0,2,5),np.linspace(0,5,5))
plt.show()

# %%
plt.figure()
plt.subplots_adjust(hspace=.25)
plt.subplot(1,1,1)
plt.scatter(np.linspace(1,2,5), np.linspace(1,2,5))
plt.subplot(2,2,2)
plt.scatter(np.linspace(1,2,4), np.linspace(1,2,4))
